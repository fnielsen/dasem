# %% [markdown]
# Four words
# ==========
# Determine which of four words is the odd one out.
#
# Data is read from a comma-separated file with four columns where the fourth column contains
# the odd-one-out. The task is to identify that one
# (without using the fact that it is in this specific column)

# %%
from everything import *
from dasem.semantic import Semantic

# %%
# Load semantic method
semantic = Semantic()

# %%
# Read dataset
four_words = read_csv('../dasem/data/four_words.csv', encoding='utf-8')

# %%
four_words.head()
# Out:
#   word1  word2     word3   word4
# 0  æble   pære  kirsebær    stol
# 1  stol   bord      reol    græs
# 2  græs    træ    blomst     bil
# 3   bil  cykel       tog    vind
# 4  vind   regn   solskin  mandag

# %%
# Identify outlier
outlier = []
for idx, words in four_words.iterrows():
    sorted_words = semantic.sort_by_outlierness(words.values[:4])
    outlier.append(sorted_words[0])

four_words['outlier'] = outlier

# %%
# Accuracy
mean(four_words.word4 == outlier)
# Out:
# 0.78000000000000003

# %%
four_words
# Out:
#                    word1                 word2                  word3  \
# 0                   æble                  pære               kirsebær
# 1                   stol                  bord                   reol
# 2                   græs                   træ                 blomst
# 3                    bil                 cykel                    tog
# 4                   vind                  regn                solskin
# 5                 mandag               tirsdag                 søndag
# 6                 tømrer              vvs-mand                snedker
# 7                   barn                   far                 mormor
# 8                  lampe            stearinlys             lommelygte
# 9                   jern                  guld              magnesium
# 10                  sjov                dårlig              vanvittig
# 11                 papir              ringbind                 blyant
# 12                  vagt            politimand        fængselsbetjent
# 13                    by               landsby                købstad
# 14               småkage            citronmåne                kringle
# 15                   dør                   væg                 vindue
# 16                klaver               trumpet             blokfløjte
# 17               fandens                  fuck                    sgu
# 18                  vand                  jord                    ild
# 19            hukommelse           intelligens                emotion
# 20            Niels Bohr           H.C. Ørsted              Ole Rømer
# 21  Lars Løkke Rasmussen  Poul Nyrup Rasmussen  Anders Fogh Rasmussen
# 22      Peter Schmeichel     Kasper Schmeichel          Brian Laudrup
# 23    Caroline Wozniacki           Steffi Graf        Serena Williams
# 24                Monaco                 Paris                 Milano
# 25                   Pia                  Lone               Marianne
# 26                  bold              fjerbold                   puck
# 27                  mave                 bryst                    ryg
# 28                   hat                kasket                    hue
# 29              ishockey                skiløb                 skihop
# 30                    gå                  løbe                 kravle
# 31                   rød                   blå                 violet
# 32               Finland               Sverige                  Norge
# 33                  Kina                 Japan               Sydkorea
# 34                 humor               komedie                 comedy
# 35          vaskemaskine            strygejern           tørretumbler
# 36            restaurant                  café                    bar
# 37                    øl                   vin               spiritus
# 38                køkken               baderum                   stue
# 39                  wing                  back                forward
# 40                 vinge          landingsstel                 propel
# 41             kartoffel            frikadelle                  salat
# 42                Viborg               Randers                  Hobro
# 43              Kattegat               Øresund                Alssund
# 44                    eg              lærketræ                æbletræ
# 45                hugorm                 pyton                   snog
# 46                    ko                    so                   hest
# 47                  ugle                 krage                   måge
# 48                  hund                   ræv                    ulv
# 49             spilletid               halvleg                 dommer
#
#                    word4             outlier
# 0                   stol                stol
# 1                   græs                græs
# 2                    bil                 bil
# 3                   vind                vind
# 4                 mandag              mandag
# 5                 tømrer              tømrer
# 6                   barn                barn
# 7                  lampe               lampe
# 8                   jern                jern
# 9                   sjov                sjov
# 10                 papir           vanvittig
# 11                  vagt                vagt
# 12                    by                vagt
# 13               småkage             småkage
# 14                   dør             kringle
# 15                klaver              klaver
# 16               fandens             fandens
# 17                  vand             fandens
# 18            hukommelse          hukommelse
# 19            Niels Bohr          Niels Bohr
# 20  Lars Løkke Rasmussen         H.C. Ørsted
# 21      Peter Schmeichel    Peter Schmeichel
# 22    Caroline Wozniacki  Caroline Wozniacki
# 23                Monaco         Steffi Graf
# 24                   Pia                 Pia
# 25                   Ole            Marianne
# 26                  mave                mave
# 27                   hat                 hat
# 28              ishockey            ishockey
# 29               fodbold             fodbold
# 30                 sidde               sidde
# 31                himmel              himmel
# 32                  Kina                Kina
# 33                Irland              Irland
# 34               beskidt             beskidt
# 35               beskidt          strygejern
# 36                    øl                  øl
# 37                køkken              køkken
# 38                    øl                  øl
# 39                 vinge               vinge
# 40             kartoffel           kartoffel
# 41                  pejs                pejs
# 42              Kattegat            Kattegat
# 43              Sjælland             Alssund
# 44                slange            lærketræ
# 45                  hund               pyton
# 46                krappe              krappe
# 47                  hund                hund
# 48                krappe              krappe
# 49                   ræv                 ræv

# %% [markdown]
# Parameters that might affect performance
# ----------------------------------------
#
# - Number of pages read
# - Use of stopwords
# - Exclusion of short pages
# - Scaling of matrix tfidf/count
# - Normalization of document
# - Factorization of matrix

# %%
def compute_accuracy(semantic, four_words):
    outlier = []
    for idx, words in four_words.iterrows():
        sorted_words = semantic.sort_by_outlierness(words.values[:4])
        outlier.append(sorted_words[0])

    accuracy = mean(four_words.word4 == outlier)
    return accuracy

# %%
max_n_pagess = [10, 100, 1000, 3000]
norms = ['l1', 'l2', None]
stop_wordss = [None, set(nltk.corpus.stopwords.words('danish'))]
use_idfs = [True, False]
sublinear_tfs = [True, False]

columns = ['accuracy', 'stop_words', 'use_idf', 'norm', 'sublinear_tf', 'max_n_pages']

n_total = len(max_n_pagess) * len(norms) * len(stop_wordss) * len(use_idfs) * \
    len(sublinear_tfs)
results = DataFrame(dtype=float, index=range(n_total), columns=columns)
n = 0
for stop_words_index, stop_words in (enumerate(stop_wordss)):
    for norm in (norms):
        for use_idf in (use_idfs):
            for sublinear_tf in (sublinear_tfs):
                for max_n_pages in (max_n_pagess):
                    results.ix[n, 'max_n_pages'] = max_n_pages
                    results.ix[n, 'stop_words'] = stop_words_index
                    results.ix[n, 'norm'] = str(norm)
                    results.ix[n, 'use_idf'] = use_idf
                    results.ix[n, 'sublinear_tf'] = sublinear_tf
                    semantic = Semantic(stop_words=stop_words, norm=norm,
                                        use_idf=use_idf, sublinear_tf=sublinear_tf,
                                        max_n_pages=max_n_pages)
                    results.ix[n, 'accuracy'] = compute_accuracy(semantic, four_words)
                    n += 1

# %%
results
# Out:
#     accuracy  stop_words use_idf  norm sublinear_tf  max_n_pages
# 0       0.02         0.0    True    l1         True         10.0
# 1       0.08         0.0    True    l1         True        100.0
# 2       0.28         0.0    True    l1         True       1000.0
# 3       0.36         0.0    True    l1         True       3000.0
# 4       0.02         0.0    True    l1        False         10.0
# 5       0.08         0.0    True    l1        False        100.0
# 6       0.26         0.0    True    l1        False       1000.0
# 7       0.34         0.0    True    l1        False       3000.0
# 8       0.00         0.0   False    l1         True         10.0
# 9       0.06         0.0   False    l1         True        100.0
# 10      0.28         0.0   False    l1         True       1000.0
# 11      0.38         0.0   False    l1         True       3000.0
# 12      0.02         0.0   False    l1        False         10.0
# 13      0.08         0.0   False    l1        False        100.0
# 14      0.28         0.0   False    l1        False       1000.0
# 15      0.36         0.0   False    l1        False       3000.0
# 16      0.02         0.0    True    l2         True         10.0
# 17      0.08         0.0    True    l2         True        100.0
# 18      0.28         0.0    True    l2         True       1000.0
# 19      0.38         0.0    True    l2         True       3000.0
# 20      0.02         0.0    True    l2        False         10.0
# 21      0.08         0.0    True    l2        False        100.0
# 22      0.30         0.0    True    l2        False       1000.0
# 23      0.38         0.0    True    l2        False       3000.0
# 24      0.02         0.0   False    l2         True         10.0
# 25      0.08         0.0   False    l2         True        100.0
# 26      0.28         0.0   False    l2         True       1000.0
# 27      0.38         0.0   False    l2         True       3000.0
# 28      0.02         0.0   False    l2        False         10.0
# 29      0.08         0.0   False    l2        False        100.0
# ..       ...         ...     ...   ...          ...          ...
# 66      0.28         1.0    True    l2         True       1000.0
# 67      0.38         1.0    True    l2         True       3000.0
# 68      0.02         1.0    True    l2        False         10.0
# 69      0.08         1.0    True    l2        False        100.0
# 70      0.30         1.0    True    l2        False       1000.0
# 71      0.38         1.0    True    l2        False       3000.0
# 72      0.02         1.0   False    l2         True         10.0
# 73      0.08         1.0   False    l2         True        100.0
# 74      0.28         1.0   False    l2         True       1000.0
# 75      0.38         1.0   False    l2         True       3000.0
# 76      0.02         1.0   False    l2        False         10.0
# 77      0.08         1.0   False    l2        False        100.0
# 78      0.30         1.0   False    l2        False       1000.0
# 79      0.40         1.0   False    l2        False       3000.0
# 80      0.02         1.0    True  None         True         10.0
# 81      0.10         1.0    True  None         True        100.0
# 82      0.26         1.0    True  None         True       1000.0
# 83      0.40         1.0    True  None         True       3000.0
# 84      0.02         1.0    True  None        False         10.0
# 85      0.10         1.0    True  None        False        100.0
# 86      0.24         1.0    True  None        False       1000.0
# 87      0.44         1.0    True  None        False       3000.0
# 88      0.02         1.0   False  None         True         10.0
# 89      0.08         1.0   False  None         True        100.0
# 90      0.28         1.0   False  None         True       1000.0
# 91      0.38         1.0   False  None         True       3000.0
# 92      0.02         1.0   False  None        False         10.0
# 93      0.08         1.0   False  None        False        100.0
# 94      0.24         1.0   False  None        False       1000.0
# 95      0.42         1.0   False  None        False       3000.0
#
# [96 rows x 6 columns]

# %%
formula = 'accuracy ~ stop_words + use_idf + norm + sublinear_tf + max_n_pages'
model = smf.glm(formula, data=results).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               accuracy   No. Observations:                   96
# Model:                            GLM   Df Residuals:                       89
# Model Family:                Gaussian   Df Model:                            6
# Link Function:               identity   Scale:                0.00336693637528
# Method:                          IRLS   Log-Likelihood:                 140.72
# Date:                Fri, 30 Sep 2016   Deviance:                      0.29966
# Time:                        14:16:05   Pearson chi2:                    0.300
# No. Iterations:                     2
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.0778      0.015      5.067      0.000       0.048       0.108
# use_idf[T.True]          0.0008      0.012      0.070      0.944      -0.022       0.024
# norm[T.l1]              -0.0125      0.015     -0.862      0.389      -0.041       0.016
# norm[T.l2]            3.296e-17      0.015   2.27e-15      1.000      -0.028       0.028
# sublinear_tf[T.True]    -0.0025      0.012     -0.211      0.833      -0.026       0.021
# stop_words            7.199e-17      0.012   6.08e-15      1.000      -0.023       0.023
# max_n_pages              0.0001   4.92e-06     23.076      0.000       0.000       0.000
# ========================================================================================
# """
